# %%
# !pip list
# Out:
# Package                       Version         Editable project location
# ----------------------------- --------------- ---------------------------------------------------------------------
# absl-py                       2.0.0
# accelerate                    0.29.3
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# annotated-types               0.7.0
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-lru                     2.0.4
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         23.1.0
# Automat                       20.2.0
# autopep8                      1.6.0
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# black                         0.0
# bleach                        4.1.0
# bokeh                         3.2.1
# boltons                       23.0.0
# botocore                      1.29.76
# Bottleneck                    1.3.5
# brotlipy                      0.7.0
# cachetools                    5.3.2
# certifi                       2023.11.17
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# click                         8.0.4
# cloudpickle                   2.2.1
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      3.0.1
# comm                          0.1.2
# conda                         23.7.4
# conda-build                   3.26.1
# conda-content-trust           0.2.0
# conda_index                   0.3.0
# conda-libmamba-solver         23.7.0
# conda-pack                    0.6.0
# conda-package-handling        2.2.0
# conda_package_streaming       0.9.0
# conda-repo-cli                1.0.75
# conda-token                   0.4.0
# conda-verify                  3.4.2
# constantly                    15.1.0
# contourpy                     1.0.5
# cookiecutter                  1.7.3
# cryptography                  41.0.3
# cssselect                     1.1.0
# ctransformers                 0.2.5
# cycler                        0.11.0
# cytoolz                       0.12.0
# daal4py                       2023.1.1
# dacite                        1.8.1
# dask                          2023.6.0
# dataclasses-json              0.5.14
# datasets                      2.12.0
# datashader                    0.15.2
# datashape                     0.5.4
# debugpy                       1.6.7
# decorator                     5.1.1
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.6
# distributed                   2023.6.0
# docstring-to-markdown         0.11
# docutils                      0.18.1
# ensure                        1.0.2
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# executing                     0.8.3
# fastjsonschema                2.16.2
# filelock                      3.9.0
# Fitness-Chatbot               0.0.0           C:\Users\mayuo\OneDrive\Documents\Machine Learning by Abraham\chatbot
# flake8                        6.0.0
# Flask                         2.2.2
# Flask-Cors                    4.0.1
# flatbuffers                   23.5.26
# fonttools                     4.25.0
# fqdn                          1.5.1
# frozenlist                    1.3.3
# fsspec                        2023.4.0
# fst-pso                       1.8.1
# future                        0.18.3
# FuzzyTM                       2.0.5
# gast                          0.5.4
# gensim                        4.3.0
# geographiclib                 2.0
# geopy                         2.4.1
# glob2                         0.7
# google-auth                   2.23.4
# google-auth-oauthlib          1.1.0
# google-pasta                  0.2.0
# googlemaps                    4.10.0
# greenlet                      2.0.1
# grpcio                        1.59.3
# gunicorn                      21.2.0
# h11                           0.14.0
# h5py                          3.9.0
# HeapDict                      1.0.1
# holoviews                     1.17.1
# htmlmin                       0.1.12
# httpcore                      1.0.5
# httpx                         0.27.0
# huggingface-hub               0.15.1
# hvplot                        0.8.4
# hyperlink                     21.0.0
# idna                          3.4
# imagecodecs                   2023.1.23
# ImageHash                     4.3.1
# imageio                       2.26.0
# imagesize                     1.4.1
# imbalanced-learn              0.12.3
# importlib-metadata            6.0.0
# incremental                   21.3.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.25.0
# ipython                       8.15.0
# ipython-genutils              0.2.0
# ipywidgets                    8.0.4
# isoduration                   20.11.0
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.0.4
# itsdangerous                  2.0.1
# jaraco.classes                3.2.1
# jedi                          0.18.1
# jellyfish                     1.0.1
# Jinja2                        3.1.2
# jinja2-time                   0.2.0
# jmespath                      0.10.0
# joblib                        1.4.2
# json5                         0.9.6
# jsonpatch                     1.33
# jsonpointer                   2.1
# jsonschema                    4.19.2
# jsonschema-specifications     2023.7.1
# jupyter                       1.0.0
# jupyter_client                7.4.9
# jupyter-console               6.6.3
# jupyter_core                  5.3.0
# jupyter-events                0.6.3
# jupyter-lsp                   2.2.0
# jupyter_server                2.10.0
# jupyter_server_fileid         0.9.0
# jupyter_server_terminals      0.4.4
# jupyter_server_ydoc           0.8.0
# jupyter-ydoc                  0.2.4
# jupyterlab                    4.0.8
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.25.1
# jupyterlab-widgets            3.0.9
# kaleido                       0.2.1
# keras                         2.15.0
# keyring                       23.13.1
# kiwisolver                    1.4.4
# langchain                     0.0.225
# langchain-community           0.0.38
# langchain-core                0.1.52
# langchainplus-sdk             0.0.20
# langsmith                     0.1.104
# lazy_loader                   0.2
# lazy-object-proxy             1.6.0
# libarchive-c                  2.9
# libclang                      16.0.6
# libmambapy                    1.5.1
# linkify-it-py                 2.0.0
# llvmlite                      0.40.0
# lmdb                          1.4.1
# locket                        1.0.0
# lxml                          4.9.3
# lz4                           4.3.2
# Markdown                      3.4.1
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.1
# marshmallow                   3.22.0
# matplotlib                    3.7.2
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mdit-py-plugins               0.3.0
# mdurl                         0.1.0
# menuinst                      1.4.19
# miniful                       0.0.6
# missingno                     0.5.2
# mistune                       0.8.4
# mkl-fft                       1.3.8
# mkl-random                    1.2.4
# mkl-service                   2.4.0
# ml-dtypes                     0.2.0
# more-itertools                8.12.0
# mpmath                        1.3.0
# msgpack                       1.0.3
# multidict                     6.0.2
# multimethod                   1.11.2
# multipledispatch              0.6.0
# multiprocess                  0.70.14
# munkres                       1.1.4
# mypy-extensions               1.0.0
# navigator-updater             0.4.0
# nbclassic                     0.5.5
# nbclient                      0.5.13
# nbconvert                     6.5.4
# nbformat                      5.9.2
# nest-asyncio                  1.5.6
# networkx                      3.1
# nltk                          3.8.1
# notebook                      7.0.6
# notebook_shim                 0.2.2
# numba                         0.57.1
# numexpr                       2.8.4
# numpy                         1.24.3
# numpydoc                      1.5.0
# oauthlib                      3.2.2
# openapi-schema-pydantic       1.2.4
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# orjson                        3.10.7
# overrides                     7.4.0
# packaging                     23.2
# pandas                        2.2.2
# pandas-profiling              3.2.0
# pandocfilters                 1.5.0
# panel                         1.2.3
# param                         1.13.0
# paramiko                      2.8.1
# parsel                        1.6.0
# parso                         0.8.3
# partd                         1.4.0
# pathlib                       1.0.1
# pathspec                      0.10.3
# patsy                         0.5.3
# pep8                          1.7.1
# pexpect                       4.8.0
# phik                          0.12.4
# pickleshare                   0.7.5
# pillow                        10.3.0
# pinecone-client               5.0.1
# pinecone-plugin-inference     1.0.3
# pinecone-plugin-interface     0.0.7
# pip                           23.2.1
# pkce                          1.0.3
# pkginfo                       1.9.6
# platformdirs                  3.10.0
# plotly                        5.9.0
# pluggy                        1.0.0
# ply                           3.11
# poyo                          0.5.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.36
# Protego                       0.1.16
# protobuf                      4.23.4
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    8.0.0
# pyarrow                       11.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.10.0
# pycosat                       0.6.4
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.2
# pydantic                      1.10.18
# pydantic_core                 2.18.2
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pyerfa                        2.0.0
# pyflakes                      3.0.1
# pyFUME                        0.2.25
# Pygments                      2.15.1
# PyJWT                         2.4.0
# pylint                        2.16.2
# pylint-venv                   2.3.0
# pyls-spyder                   0.4.0
# PyNaCl                        1.5.0
# pyodbc                        4.0.34
# pyOpenSSL                     23.2.0
# pyparsing                     3.0.9
# pypdf                         4.3.1
# PyQt5                         5.15.7
# PyQt5-sip                     12.11.0
# PyQtWebEngine                 5.15.4
# pyrsistent                    0.18.0
# PySocks                       1.7.1
# pytest                        7.4.0
# python-box                    6.0.2
# python-dateutil               2.8.2
# python-dotenv                 0.21.0
# python-json-logger            2.0.7
# python-lsp-black              1.2.1
# python-lsp-jsonrpc            1.0.0
# python-lsp-server             1.7.2
# python-slugify                5.0.2
# python-snappy                 0.6.1
# pytoolconfig                  1.2.5
# pytz                          2023.3.post1
# pyviz-comms                   2.3.0
# PyWavelets                    1.4.1
# pywin32                       305.1
# pywin32-ctypes                0.2.0
# pywinpty                      2.0.10
# PyYAML                        6.0
# pyzmq                         25.1.0
# QDarkStyle                    3.0.2
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.4.2
# QtPy                          2.2.0
# queuelib                      1.5.0
# referencing                   0.30.2
# regex                         2022.7.9
# requests                      2.31.0
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# requests-toolbelt             1.0.0
# responses                     0.13.3
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rope                          1.7.0
# rpds-py                       0.10.6
# rsa                           4.9
# Rtree                         1.0.1
# ruamel.yaml                   0.17.21
# ruamel-yaml-conda             0.17.21
# s3fs                          2023.4.0
# safetensors                   0.3.2
# scikit-image                  0.20.0
# scikit-learn                  1.5.0
# scikit-learn-intelex          20230426.121932
# scipy                         1.11.1
# Scrapy                        2.8.0
# seaborn                       0.12.2
# Send2Trash                    1.8.2
# sentence-transformers         2.2.2
# sentencepiece                 0.2.0
# service-identity              18.1.0
# setuptools                    68.0.0
# shap                          0.46.0
# simpful                       2.11.1
# sip                           6.6.2
# six                           1.16.0
# slicer                        0.0.8
# smart-open                    5.2.1
# sniffio                       1.2.0
# snowballstemmer               2.2.0
# sortedcontainers              2.4.0
# soupsieve                     2.4
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.4.3
# spyder-kernels                2.4.4
# SQLAlchemy                    1.4.39
# stack-data                    0.2.0
# statsmodels                   0.14.0
# svgling                       0.4.0
# svgwrite                      1.4.3
# sympy                         1.11.1
# tables                        3.8.0
# tabulate                      0.8.10
# tangled-up-in-unicode         0.2.0
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.15.1
# tensorboard-data-server       0.7.2
# tensorflow                    2.15.0
# tensorflow-estimator          2.15.0
# tensorflow-intel              2.15.0
# tensorflow-io-gcs-filesystem  0.31.0
# termcolor                     2.3.0
# terminado                     0.17.1
# text-unidecode                1.3
# textdistance                  4.2.1
# threadpoolctl                 3.5.0
# three-merge                   0.1.1
# tifffile                      2023.4.12
# tinycss2                      1.2.1
# tldextract                    3.2.0
# tokenizers                    0.13.2
# toml                          0.10.2
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         2.4.0
# torchvision                   0.19.0
# tornado                       6.3.2
# tqdm                          4.65.0
# traitlets                     5.7.1
# transformers                  4.32.1
# Twisted                       22.10.0
# twisted-iocpsupport           1.0.2
# typeguard                     4.3.0
# types-PyYAML                  6.0.12.20240311
# typing_extensions             4.10.0
# typing-inspect                0.9.0
# tzdata                        2023.3
# uc-micro-py                   1.0.1
# ujson                         5.4.0
# Unidecode                     1.2.0
# uri-template                  1.3.0
# urllib3                       1.26.16
# visions                       0.7.6
# w3lib                         1.21.0
# waitress                      2.1.2
# watchdog                      2.1.6
# wcwidth                       0.2.5
# webcolors                     24.6.0
# webencodings                  0.5.1
# websocket-client              0.58.0
# Werkzeug                      2.2.3
# whatthepatch                  1.0.2
# wheel                         0.38.4
# widgetsnbextension            4.0.5
# win-inet-pton                 1.1.0
# wordcloud                     1.9.3
# wrapt                         1.14.1
# xarray                        2023.6.0
# xgboost                       2.1.0
# xlwings                       0.29.1
# xxhash                        2.0.2
# xyzservices                   2022.9.0
# y-py                          0.5.9
# yapf                          0.31.0
# yarl                          1.8.1
# ydata-profiling               4.8.3
# ypy-websocket                 0.8.2
# zict                          2.2.0
# zipp                          3.11.0
# zope.interface                5.4.0
# zstandard                     0.19.0

# %%
# !pip install bitsandbytes trl
# Out:
# Collecting bitsandbytes
#   Obtaining dependency information for bitsandbytes from https://files.pythonhosted.org/packages/5f/f5/11bddebb5addc0a005b0c1cecc6e4c6e4055ad7b860bdcbf6374e12a51f5/bitsandbytes-0.44.1-py3-none-win_amd64.whl.metadata
#   Downloading bitsandbytes-0.44.1-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting trl
#   Obtaining dependency information for trl from https://files.pythonhosted.org/packages/2f/62/fd2c8e9edebad14084370fa88cf6cb56816926040658f5bfcf5eab9ad8c7/trl-0.11.1-py3-none-any.whl.metadata
#   Downloading trl-0.11.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: torch in c:\users\mayuo\anaconda3\lib\site-packages (from bitsandbytes) (2.4.0)
# Requirement already satisfied: numpy in c:\users\mayuo\anaconda3\lib\site-packages (from bitsandbytes) (1.24.3)
# Collecting transformers>=4.40.0 (from trl)
#   Obtaining dependency information for transformers>=4.40.0 from https://files.pythonhosted.org/packages/17/f2/f01ea29c8eff8e749d96525a17c2d3ec02656cec9a80c20fb3e74dba4b04/transformers-4.45.1-py3-none-any.whl.metadata
#   Downloading transformers-4.45.1-py3-none-any.whl.metadata (44 kB)
#      ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/44.4 kB ? eta -:--:--
#      -------------------------------------- 44.4/44.4 kB 726.3 kB/s eta 0:00:00
# Requirement already satisfied: accelerate in c:\users\mayuo\anaconda3\lib\site-packages (from trl) (0.29.3)
# Requirement already satisfied: datasets in c:\users\mayuo\anaconda3\lib\site-packages (from trl) (2.12.0)
# Collecting tyro>=0.5.11 (from trl)
#   Obtaining dependency information for tyro>=0.5.11 from https://files.pythonhosted.org/packages/72/51/1b9f7ed08573cde2e1bfc0039a7fa9c8f76caba048f6eaf33bbc5aa5f18c/tyro-0.8.11-py3-none-any.whl.metadata
#   Downloading tyro-0.8.11-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: filelock in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (4.10.0)
# Requirement already satisfied: sympy in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (1.11.1)
# Requirement already satisfied: networkx in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (3.1)
# Requirement already satisfied: jinja2 in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\mayuo\anaconda3\lib\site-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (0.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (2022.7.9)
# Requirement already satisfied: requests in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (2.31.0)
# Collecting safetensors>=0.4.1 (from transformers>=4.40.0->trl)
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/6d/41/948c96c8a7e9fef57c2e051f1871c108a6dbbc6d285598bdb1d89b98617c/safetensors-0.4.5-cp311-none-win_amd64.whl.metadata
#   Downloading safetensors-0.4.5-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.40.0->trl)
#   Obtaining dependency information for tokenizers<0.21,>=0.20 from https://files.pythonhosted.org/packages/c0/3c/9228601e180b177755fd9f35cbb229c13f1919a55f07a602b1bd7d716470/tokenizers-0.20.0-cp311-none-win_amd64.whl.metadata
#   Downloading tokenizers-0.20.0-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\mayuo\anaconda3\lib\site-packages (from transformers>=4.40.0->trl) (4.65.0)
# Collecting docstring-parser>=0.16 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for docstring-parser>=0.16 from https://files.pythonhosted.org/packages/d5/7c/e9fcff7623954d86bdc17782036cbf715ecab1bec4847c008557affe1ca8/docstring_parser-0.16-py3-none-any.whl.metadata
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting rich>=11.1.0 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for rich>=11.1.0 from https://files.pythonhosted.org/packages/ab/71/cd9549551f1aa11cf7e5f92bae5817979e8b3a19e31e8810c15f3f45c311/rich-13.9.1-py3-none-any.whl.metadata
#   Downloading rich-13.9.1-py3-none-any.whl.metadata (18 kB)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Obtaining dependency information for shtab>=1.5.6 from https://files.pythonhosted.org/packages/e2/d1/a1d3189e7873408b9dc396aef0d7926c198b0df2aa3ddb5b539d3e89a70f/shtab-1.7.1-py3-none-any.whl.metadata
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: colorama>=0.4.0 in c:\users\mayuo\anaconda3\lib\site-packages (from tyro>=0.5.11->trl) (0.4.6)
# Requirement already satisfied: psutil in c:\users\mayuo\anaconda3\lib\site-packages (from accelerate->trl) (5.9.0)
# Requirement already satisfied: pyarrow>=8.0.0 in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (11.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (0.3.6)
# Requirement already satisfied: pandas in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (2.2.2)
# Requirement already satisfied: xxhash in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (2.0.2)
# Requirement already satisfied: multiprocess in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (0.70.14)
# Requirement already satisfied: aiohttp in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (3.8.5)
# Requirement already satisfied: responses<0.19 in c:\users\mayuo\anaconda3\lib\site-packages (from datasets->trl) (0.13.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mayuo\anaconda3\lib\site-packages (from aiohttp->datasets->trl) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayuo\anaconda3\lib\site-packages (from requests->transformers>=4.40.0->trl) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayuo\anaconda3\lib\site-packages (from requests->transformers>=4.40.0->trl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayuo\anaconda3\lib\site-packages (from requests->transformers>=4.40.0->trl) (2023.11.17)
# Requirement already satisfied: six in c:\users\mayuo\anaconda3\lib\site-packages (from responses<0.19->datasets->trl) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mayuo\anaconda3\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mayuo\anaconda3\lib\site-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.15.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mayuo\anaconda3\lib\site-packages (from jinja2->torch->bitsandbytes) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mayuo\anaconda3\lib\site-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mayuo\anaconda3\lib\site-packages (from pandas->datasets->trl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mayuo\anaconda3\lib\site-packages (from pandas->datasets->trl) (2023.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mayuo\anaconda3\lib\site-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mayuo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.0)
# Downloading bitsandbytes-0.44.1-py3-none-win_amd64.whl (121.5 MB)
#    ---------------------------------------- 0.0/121.5 MB ? eta -:--:--
#    ---------------------------------------- 0.2/121.5 MB 14.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.7/121.5 MB 11.4 MB/s eta 0:00:11
#    ---------------------------------------- 1.0/121.5 MB 9.5 MB/s eta 0:00:13
#    ---------------------------------------- 1.5/121.5 MB 9.3 MB/s eta 0:00:13
#     --------------------------------------- 2.4/121.5 MB 11.9 MB/s eta 0:00:11
#    - -------------------------------------- 3.3/121.5 MB 13.0 MB/s eta 0:00:10
#    - -------------------------------------- 4.2/121.5 MB 14.0 MB/s eta 0:00:09
#    - -------------------------------------- 4.4/121.5 MB 12.7 MB/s eta 0:00:10
#    - -------------------------------------- 4.9/121.5 MB 12.7 MB/s eta 0:00:10
#    -- ------------------------------------- 6.1/121.5 MB 13.5 MB/s eta 0:00:09
#    -- ------------------------------------- 7.2/121.5 MB 14.8 MB/s eta 0:00:08
#    -- ------------------------------------- 7.3/121.5 MB 13.7 MB/s eta 0:00:09
#    -- ------------------------------------- 7.8/121.5 MB 13.4 MB/s eta 0:00:09
#    -- ------------------------------------- 8.2/121.5 MB 13.1 MB/s eta 0:00:09
#    --- ------------------------------------ 9.3/121.5 MB 13.8 MB/s eta 0:00:09
#    --- ------------------------------------ 10.4/121.5 MB 14.6 MB/s eta 0:00:08
#    --- ------------------------------------ 11.6/121.5 MB 16.8 MB/s eta 0:00:07
#    --- ------------------------------------ 11.9/121.5 MB 16.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 13.4/121.5 MB 16.8 MB/s eta 0:00:07
#    ---- ----------------------------------- 14.1/121.5 MB 16.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 15.2/121.5 MB 18.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 16.5/121.5 MB 18.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 17.4/121.5 MB 18.2 MB/s eta 0:00:06
#    ------ --------------------------------- 18.6/121.5 MB 22.6 MB/s eta 0:00:05
#    ------ --------------------------------- 18.9/121.5 MB 20.5 MB/s eta 0:00:06
#    ------ --------------------------------- 19.8/121.5 MB 20.5 MB/s eta 0:00:05
#    ------ --------------------------------- 20.8/121.5 MB 20.5 MB/s eta 0:00:05
#    ------- -------------------------------- 21.9/121.5 MB 20.5 MB/s eta 0:00:05
#    ------- -------------------------------- 23.3/121.5 MB 21.8 MB/s eta 0:00:05
#    ------- -------------------------------- 23.7/121.5 MB 20.5 MB/s eta 0:00:05
#    ------- -------------------------------- 23.8/121.5 MB 18.7 MB/s eta 0:00:06
#    ------- -------------------------------- 24.3/121.5 MB 17.7 MB/s eta 0:00:06
#    -------- ------------------------------- 25.3/121.5 MB 18.2 MB/s eta 0:00:06
#    -------- ------------------------------- 26.4/121.5 MB 18.2 MB/s eta 0:00:06
#    --------- ------------------------------ 27.5/121.5 MB 18.2 MB/s eta 0:00:06
#    --------- ------------------------------ 28.6/121.5 MB 18.2 MB/s eta 0:00:06
#    --------- ------------------------------ 29.9/121.5 MB 19.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 31.1/121.5 MB 20.5 MB/s eta 0:00:05
#    ---------- ----------------------------- 32.2/121.5 MB 19.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 32.8/121.5 MB 19.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 33.6/121.5 MB 19.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 34.7/121.5 MB 22.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 35.7/121.5 MB 23.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 36.0/121.5 MB 21.1 MB/s eta 0:00:05
#    ------------ --------------------------- 36.5/121.5 MB 20.5 MB/s eta 0:00:05
#    ------------ --------------------------- 36.8/121.5 MB 18.7 MB/s eta 0:00:05
#    ------------ --------------------------- 38.0/121.5 MB 18.7 MB/s eta 0:00:05
#    ------------ --------------------------- 38.5/121.5 MB 18.2 MB/s eta 0:00:05
#    ------------ --------------------------- 39.4/121.5 MB 17.3 MB/s eta 0:00:05
#    ------------- -------------------------- 39.5/121.5 MB 16.0 MB/s eta 0:00:06
#    ------------- -------------------------- 40.3/121.5 MB 15.6 MB/s eta 0:00:06
#    ------------- -------------------------- 41.1/121.5 MB 15.2 MB/s eta 0:00:06
#    ------------- -------------------------- 41.6/121.5 MB 15.2 MB/s eta 0:00:06
#    ------------- -------------------------- 42.2/121.5 MB 14.2 MB/s eta 0:00:06
#    -------------- ------------------------- 42.9/121.5 MB 13.9 MB/s eta 0:00:06
#    -------------- ------------------------- 44.1/121.5 MB 14.6 MB/s eta 0:00:06
#    -------------- ------------------------- 45.3/121.5 MB 15.2 MB/s eta 0:00:06
#    --------------- ------------------------ 46.3/121.5 MB 15.6 MB/s eta 0:00:05
#    --------------- ------------------------ 47.8/121.5 MB 18.2 MB/s eta 0:00:05
#    ---------------- ----------------------- 49.0/121.5 MB 18.7 MB/s eta 0:00:04
#    ---------------- ----------------------- 49.8/121.5 MB 20.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 50.9/121.5 MB 21.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 51.9/121.5 MB 22.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 52.6/121.5 MB 23.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 53.6/121.5 MB 22.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 54.3/121.5 MB 21.8 MB/s eta 0:00:04
#    ------------------ --------------------- 55.4/121.5 MB 21.9 MB/s eta 0:00:04
#    ------------------ --------------------- 55.6/121.5 MB 21.1 MB/s eta 0:00:04
#    ------------------ --------------------- 56.0/121.5 MB 18.7 MB/s eta 0:00:04
#    ------------------ --------------------- 56.9/121.5 MB 18.7 MB/s eta 0:00:04
#    ------------------- -------------------- 58.0/121.5 MB 18.7 MB/s eta 0:00:04
#    ------------------- -------------------- 59.1/121.5 MB 18.2 MB/s eta 0:00:04
#    ------------------- -------------------- 60.1/121.5 MB 18.7 MB/s eta 0:00:04
#    -------------------- ------------------- 61.1/121.5 MB 18.2 MB/s eta 0:00:04
#    -------------------- ------------------- 61.9/121.5 MB 18.2 MB/s eta 0:00:04
#    -------------------- ------------------- 62.6/121.5 MB 17.7 MB/s eta 0:00:04
#    -------------------- ------------------- 63.1/121.5 MB 17.7 MB/s eta 0:00:04
#    -------------------- ------------------- 63.5/121.5 MB 16.8 MB/s eta 0:00:04
#    --------------------- ------------------ 63.9/121.5 MB 16.4 MB/s eta 0:00:04
#    --------------------- ------------------ 64.1/121.5 MB 16.0 MB/s eta 0:00:04
#    --------------------- ------------------ 64.2/121.5 MB 14.9 MB/s eta 0:00:04
#    --------------------- ------------------ 64.6/121.5 MB 13.9 MB/s eta 0:00:05
#    --------------------- ------------------ 65.3/121.5 MB 13.6 MB/s eta 0:00:05
#    --------------------- ------------------ 65.5/121.5 MB 13.4 MB/s eta 0:00:05
#    --------------------- ------------------ 65.8/121.5 MB 12.8 MB/s eta 0:00:05
#    ---------------------- ----------------- 66.8/121.5 MB 13.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 67.3/121.5 MB 13.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 67.6/121.5 MB 12.6 MB/s eta 0:00:05
#    ---------------------- ----------------- 68.4/121.5 MB 12.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 68.9/121.5 MB 11.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 69.7/121.5 MB 11.7 MB/s eta 0:00:05
#    ----------------------- ---------------- 70.7/121.5 MB 11.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 71.5/121.5 MB 11.7 MB/s eta 0:00:05
#    ----------------------- ---------------- 72.7/121.5 MB 12.1 MB/s eta 0:00:05
#    ------------------------ --------------- 73.7/121.5 MB 13.1 MB/s eta 0:00:04
#    ------------------------ --------------- 75.1/121.5 MB 16.4 MB/s eta 0:00:03
#    ------------------------- -------------- 76.1/121.5 MB 18.2 MB/s eta 0:00:03
#    ------------------------- -------------- 77.1/121.5 MB 18.7 MB/s eta 0:00:03
#    ------------------------- -------------- 78.1/121.5 MB 20.5 MB/s eta 0:00:03
#    ------------------------- -------------- 78.6/121.5 MB 21.1 MB/s eta 0:00:03
#    -------------------------- ------------- 79.6/121.5 MB 21.1 MB/s eta 0:00:02
#    -------------------------- ------------- 80.1/121.5 MB 20.5 MB/s eta 0:00:03
#    -------------------------- ------------- 81.4/121.5 MB 21.1 MB/s eta 0:00:02
#    --------------------------- ------------ 82.3/121.5 MB 20.5 MB/s eta 0:00:02
#    --------------------------- ------------ 83.5/121.5 MB 21.1 MB/s eta 0:00:02
#    --------------------------- ------------ 84.7/121.5 MB 21.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 85.7/121.5 MB 21.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 87.1/121.5 MB 21.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 88.4/121.5 MB 22.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 89.4/121.5 MB 24.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 90.4/121.5 MB 25.2 MB/s eta 0:00:02
#    ------------------------------ --------- 91.3/121.5 MB 24.2 MB/s eta 0:00:02
#    ------------------------------ --------- 92.0/121.5 MB 23.4 MB/s eta 0:00:02
#    ------------------------------ --------- 93.1/121.5 MB 23.4 MB/s eta 0:00:02
#    ------------------------------- -------- 94.1/121.5 MB 23.4 MB/s eta 0:00:02
#    ------------------------------- -------- 95.1/121.5 MB 21.9 MB/s eta 0:00:02
#    ------------------------------- -------- 96.3/121.5 MB 22.5 MB/s eta 0:00:02
#    -------------------------------- ------- 97.4/121.5 MB 22.6 MB/s eta 0:00:02
#    -------------------------------- ------- 98.5/121.5 MB 21.9 MB/s eta 0:00:02
#    -------------------------------- ------- 99.9/121.5 MB 22.6 MB/s eta 0:00:01
#    -------------------------------- ------ 101.0/121.5 MB 23.4 MB/s eta 0:00:01
#    -------------------------------- ------ 102.3/121.5 MB 25.2 MB/s eta 0:00:01
#    --------------------------------- ----- 103.2/121.5 MB 24.2 MB/s eta 0:00:01
#    --------------------------------- ----- 104.2/121.5 MB 24.2 MB/s eta 0:00:01
#    --------------------------------- ----- 105.2/121.5 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 106.4/121.5 MB 24.3 MB/s eta 0:00:01
#    ---------------------------------- ---- 107.6/121.5 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------- ---- 108.8/121.5 MB 25.2 MB/s eta 0:00:01
#    ----------------------------------- --- 109.8/121.5 MB 23.4 MB/s eta 0:00:01
#    ----------------------------------- --- 110.9/121.5 MB 23.4 MB/s eta 0:00:01
#    ----------------------------------- --- 112.0/121.5 MB 23.4 MB/s eta 0:00:01
#    ------------------------------------ -- 112.7/121.5 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ -- 113.9/121.5 MB 23.4 MB/s eta 0:00:01
#    ------------------------------------ -- 114.6/121.5 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------- - 115.5/121.5 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------- - 116.3/121.5 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------- - 116.7/121.5 MB 20.5 MB/s eta 0:00:01
#    ------------------------------------- - 117.2/121.5 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- - 118.0/121.5 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  119.0/121.5 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  120.0/121.5 MB 18.7 MB/s eta 0:00:01
#    --------------------------------------  120.9/121.5 MB 18.2 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    --------------------------------------  121.4/121.5 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 121.5/121.5 MB 9.2 MB/s eta 0:00:00
# Downloading trl-0.11.1-py3-none-any.whl (318 kB)
#    ---------------------------------------- 0.0/318.4 kB ? eta -:--:--
#    --------------------------------------- 318.4/318.4 kB 20.5 MB/s eta 0:00:00
# Downloading transformers-4.45.1-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.2/9.9 MB 24.4 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.9 MB 24.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/9.9 MB 18.9 MB/s eta 0:00:01
#    -------------- ------------------------- 3.6/9.9 MB 19.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.3/9.9 MB 19.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.7/9.9 MB 21.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.0/9.9 MB 22.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.3/9.9 MB 23.2 MB/s eta 0:00:01
#    ------------------------------------- -- 9.3/9.9 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------  9.9/9.9 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 21.1 MB/s eta 0:00:00
# Downloading tyro-0.8.11-py3-none-any.whl (105 kB)
#    ---------------------------------------- 0.0/105.9 kB ? eta -:--:--
#    ---------------------------------------- 105.9/105.9 kB 6.0 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading rich-13.9.1-py3-none-any.whl (242 kB)
#    ---------------------------------------- 0.0/242.1 kB ? eta -:--:--
#    ---------------------------------------- 242.1/242.1 kB ? eta 0:00:00
# Downloading safetensors-0.4.5-cp311-none-win_amd64.whl (285 kB)
#    ---------------------------------------- 0.0/286.0 kB ? eta -:--:--
#    ---------------------------------------- 286.0/286.0 kB ? eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading tokenizers-0.20.0-cp311-none-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 16.3 MB/s eta 0:00:01
#    -------------------------------- ------- 1.9/2.3 MB 20.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 21.1 MB/s eta 0:00:00
# Installing collected packages: shtab, safetensors, docstring-parser, rich, tyro, tokenizers, bitsandbytes, transformers, trl
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.3.2
#     Uninstalling safetensors-0.3.2:
#       Successfully uninstalled safetensors-0.3.2
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.13.2
#     Uninstalling tokenizers-0.13.2:
#       Successfully uninstalled tokenizers-0.13.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.32.1
#     Uninstalling transformers-4.32.1:
#       Successfully uninstalled transformers-4.32.1
# Successfully installed bitsandbytes-0.44.1 docstring-parser-0.16 rich-13.9.1 safetensors-0.4.5 shtab-1.7.1 tokenizers-0.20.0 transformers-4.45.1 trl-0.11.1 tyro-0.8.11

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging
)

from peft import LoraConfig, PeftModel
from trl import SFTTrainer
# Out:
# WARNING:tensorflow:From C:\Users\mayuo\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\mayuo\anaconda3\Lib\site-packages\threadpoolctl.py:1214: RuntimeWarning:
# Found Intel OpenMP ('libiomp') and LLVM OpenMP ('libomp') loaded at
# the same time. Both libraries are known to be incompatible and this
# can cause random crashes or deadlocks on Linux when loaded in the
# same Python program.
# Using threadpoolctl may cause crashes or deadlocks. For more
# information and possible workarounds, please see
#     https://github.com/joblib/threadpoolctl/blob/master/multiple_openmp.md
#
#   warnings.warn(msg, RuntimeWarning)

# %%
# The model I want to train
model_name = "NousResearch/Llama-2-7b-chat-hf"
# the data set that would be used for this fine-tunning
dataset_name = "mlabonne/guanaco-llama2-1k"
# then I have to give it a new model name:
new_model = "Llama-2-7b-chat-LoRA-finetune"

# %%
# QloRA parameters
# rank
lora_r = 64
# Alpha parameter for LoRA scaling
lora_alpha = 16
# dropout for LoRA layers
lora_dropout = 0.1

# %%
# bitsandbytes parameters
# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

# %%
# TrainingArguments parameters
# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

# %%
# SFT parameters
# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %% [markdown]
# ### Data loading and setting up the environment
